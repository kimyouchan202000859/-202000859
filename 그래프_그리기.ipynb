# %% [markdown]
# <a href="https://colab.research.google.com/github/kimyouchan202000859/python/blob/main/%EA%B7%B8%EB%9E%98%ED%94%84_%EA%B7%B8%EB%A6%AC%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x):
  return x**2 + np.sin(3*x+7)
x = np.arange(0,2,0.01)
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(f(x))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a**2 + (1/5)* b**4 +2* np.cos(a*b)

def grad_f(a,b): # gradient
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] # to store all thetas
	theta = theta0     # initial values for thetas
	# main loop by iterations:
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) #함수 f(x,y)의 gradient
		# update parameters:
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-2, -2], iters =30, alpha = 0.02)


fig = plt.figure(figsize=(15, 5))
ax = fig.gca(projection='3d')
#plt.hold(True)
a = np.arange(-2.5, 2.5, 0.1)
b = np.arange(-2.5, 2.5, 0.1)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
## c= 0 ## 최소값을 찾기 위한 부분
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

##plt.axis('equal')

plt.show()
# Out:
# [5.89271276 3.66224282 2.8158664  2.4551792  2.27623229 2.17629843
#  2.11527206 2.07534892 2.047784   2.02792331 2.0131224  2.00179351
#  1.99293693 1.98589637 1.98022487 1.97560794 1.97181785 1.96868555
#  1.96608281 1.96391055 1.96209098 1.96056229 1.95927474 1.95818799
#  1.95726908 1.95649087 1.95583092 1.95527059 1.95479434 1.95438916
#  1.95404416]

# %%
import pandas as pd
import seaborn as sns
targetUrl_iris="https://raw.githubusercontent.com/kimyouchan202000859/python/main/caffeine.csv"
irisData = pd.read_csv(targetUrl_iris)
print(irisData.shape)

print(irisData.head())

irisData.tail()
# Out:
# (610, 5)
#                          drink  Volume (ml)  Calories  Caffeine (mg)    type
# 0                 Costa Coffee   256.993715         0            277  Coffee
# 1  Coffee Friend Brewed Coffee   250.191810         0            145  Coffee
# 2           Hell Energy Coffee   250.191810       150            100  Coffee
# 3           Killer Coffee (AU)   250.191810         0            430  Coffee
# 4                 Nescafe Gold   250.191810         0             66  Coffee
#                          drink  Volume (ml)  Calories  Caffeine (mg)   type
# 605   Pep Talk Sparkling Water      354.882         0             55  Water
# 606        Polar Seltzer Water      354.882         0              0  Water
# 607     Yerbae Sparkling Water      354.882         0            100  Water
# 608                Tonic Water      295.735       110              0  Water
# 609  MiO Energy Water Enhancer      236.588         0             60  Water

# %%
sns.set_theme()
sns.set(rc={"figure.dpi":300}) #이미지 품질 설정
sns.set(rc={"figure.figsize":(6,3)}) ## 크기설정
sns.scatterplot(x="Volume (ml)", y ="Calories", data=irisData, hue ='Caffeine (mg)')

# %%
sns.histplot( y= "Volume (ml)", data = irisData)

# %%
sns.histplot( x= "Calories", data = irisData)

# %%
sns.histplot( x= "Calories", data = irisData, kde = "True")

# %%
sns.histplot( x= "Volume (ml)", data = irisData, hue = "type")

# %%
sns.barplot(x="type", y="Calories", data =irisData)
sns.set(font_scale=0.5)

# %%
sns.boxplot(x="type", y="Calories", data=irisData)
